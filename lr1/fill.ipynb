# %%
import pandas as pd
import random
import faker
import uuid
import psycopg2
from psycopg2.extras import register_uuid
from datetime import datetime, date, timedelta, time

# %%
name_gen = faker.Faker()
data = pd.read_csv('drug_consumption_transformed.csv')

education_map = {
    'Left School Before 16 years': 0,
    'Left School at 16 years': 1,
    'Left School at 17 years': 2,
    'Left School at 18 years': 3,
    'Some College,No Certificate Or Degree': 4,
    'Professional Certificate/ Diploma': 5,
    'University Degree': 6,
    'Masters Degree': 7,
    'Doctorate Degree': 8,
}

# %% [markdown]
# ### doctors

# %%
doctors = []
for i in range(51):
    gender = random.randint(1, 3) % 2 == 1
    doctors.append(
        {
            'id': uuid.uuid4(),
            'fio': name_gen.name_male() if gender else name_gen.name_female(),
            'birthdate': date.today() - timedelta(days=random.randint(28 * 365, 60 * 365)),
            'gender': gender,
            'room': i
        }
    )
doctors[:5]
# Out:
# [{'id': UUID('2e6cd8f8-a11b-4014-8d0a-e5bb2fffeb3f'),
#   'fio': 'Don Carter',
#   'birthdate': datetime.date(1981, 11, 13),
#   'gender': True,
#   'room': 0},
#  {'id': UUID('9ad35a58-bb30-4f41-8110-c065ac5e2be9'),
#   'fio': 'Paul Harris',
#   'birthdate': datetime.date(1994, 4, 4),
#   'gender': True,
#   'room': 1},
#  {'id': UUID('a77a38bb-6140-42fa-b26b-9dfd40ceec18'),
#   'fio': 'Brent Reed',
#   'birthdate': datetime.date(1986, 12, 12),
#   'gender': True,
#   'room': 2},
#  {'id': UUID('414849d3-a9e1-4ee6-b507-e82a825040cc'),
#   'fio': 'James Hernandez',
#   'birthdate': datetime.date(1969, 6, 1),
#   'gender': True,
#   'room': 3},
#  {'id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'fio': 'Christopher Braun',
#   'birthdate': datetime.date(1965, 5, 25),
#   'gender': True,
#   'room': 4}]

# %% [markdown]
# ### drugs

# %%
drugs = []
drugs_dict = {}
drugs.append({'id': uuid.uuid4(), 'name': 'Alcohol', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Amphet', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Amyl', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Benzos', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Caff', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Cannabis', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Choc', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Coke', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Crack', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Ecstasy', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Heroin', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Ketamine', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Legalh', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'LSD', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Meth', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Mushrooms', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Nicotine', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'Semer', 'description': ''})
drugs.append({'id': uuid.uuid4(), 'name': 'VSA', 'description': ''})
for drug in drugs:
    drugs_dict[drug['name']] = drug['id']
drugs
# Out:
# [{'id': UUID('c89ab7ee-3fb5-4e70-b817-46d035884316'),
#   'name': 'Alcohol',
#   'description': ''},
#  {'id': UUID('37b4e564-6f6b-4de4-9c77-9f54d5537c64'),
#   'name': 'Amphet',
#   'description': ''},
#  {'id': UUID('5b5c4155-b2c0-4b9c-81f0-fd9cdd793db5'),
#   'name': 'Amyl',
#   'description': ''},
#  {'id': UUID('98421806-3dcc-4aac-aff9-fab436d7a3f1'),
#   'name': 'Benzos',
#   'description': ''},
#  {'id': UUID('19acf24a-ac5b-44dd-b41b-d8bc83fcd1a4'),
#   'name': 'Caff',
#   'description': ''},
#  {'id': UUID('7eb9ce6c-a0bb-4fc0-a1ca-df941d6f8a91'),
#   'name': 'Cannabis',
#   'description': ''},
#  {'id': UUID('2a99b252-21a8-4dd5-aa8e-7cc18b1407ff'),
#   'name': 'Choc',
#   'description': ''},
#  {'id': UUID('5617464c-3f09-4e6d-bb6e-409c4a49e715'),
#   'name': 'Coke',
#   'description': ''},
#  {'id': UUID('246f544f-f711-4ca5-92b2-a8cfb9f0ec05'),
#   'name': 'Crack',
#   'description': ''},
#  {'id': UUID('a167d54f-7f07-44bf-b5ca-4ee5995697ac'),
#   'name': 'Ecstasy',
#   'description': ''},
#  {'id': UUID('d1bb5688-0dbf-4b10-a982-d152b33ceb03'),
#   'name': 'Heroin',
#   'description': ''},
#  {'id': UUID('98183169-efb0-43f0-b6fb-796e5cc3a6c8'),
#   'name': 'Ketamine',
#   'description': ''},
#  {'id': UUID('0c0b948a-8794-4c05-be0b-05192472c410'),
#   'name': 'Legalh',
#   'description': ''},
#  {'id': UUID('7d692991-9d90-48fd-87f6-28c832d2c254'),
#   'name': 'LSD',
#   'description': ''},
#  {'id': UUID('0762d2d5-3a35-4aba-8f22-93b580c50abe'),
#   'name': 'Meth',
#   'description': ''},
#  {'id': UUID('6aeba1fa-9fbc-4298-95d3-8ae55a19ac9a'),
#   'name': 'Mushrooms',
#   'description': ''},
#  {'id': UUID('d2bc5d44-3a55-4d8e-8e04-a4cc39318709'),
#   'name': 'Nicotine',
#   'description': ''},
#  {'id': UUID('9b9a0069-c5b0-494b-b0eb-be84b0baf1fd'),
#   'name': 'Semer',
#   'description': ''},
#  {'id': UUID('31d78fa8-8b8e-439c-a442-bfe2513a24a0'),
#   'name': 'VSA',
#   'description': ''}]

# %% [markdown]
# ### patients

# %%
patients = []
patients_personalities = []
patients_consumption = []

for idx, row in data.iterrows():
    patient_id = uuid.uuid4()
    patients.append({
        'id': patient_id,
        'fio': name_gen.name_male() if row['Gender'] else name_gen.name_female(),
        'birthdate': date.today() - timedelta(days=random.randint(1, 365) + 365 * row['Age']),
        'gender': row['Gender'],
        'ethnicity': row['Ethnicity'],
        'education': education_map[row['Education']],
    })
    patients_personalities.append({
        'patient_id': patient_id,
        'n_score': row['Nscore'],
        'e_score': row['Escore'],
        'o_score': row['Oscore'],
        'c_score': row['Cscore'],
        'impulsive': row['Impulsive'],
        'sensation': row['SS']
    })
    for drug in drugs:
        if row[drug['name']] != 'CL0':
            patients_consumption.append({
                'patient_id': patient_id,
                'drug_id': drug['id'],
                'usage': row[drug['name']]
            })

patients_consumption[:30]
# Out:
# [{'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('c89ab7ee-3fb5-4e70-b817-46d035884316'),
#   'usage': 'CL5'},
#  {'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('37b4e564-6f6b-4de4-9c77-9f54d5537c64'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('98421806-3dcc-4aac-aff9-fab436d7a3f1'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('19acf24a-ac5b-44dd-b41b-d8bc83fcd1a4'),
#   'usage': 'CL6'},
#  {'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('2a99b252-21a8-4dd5-aa8e-7cc18b1407ff'),
#   'usage': 'CL5'},
#  {'patient_id': UUID('a4a86a33-586b-4a43-ad49-abdf32ea5bd4'),
#   'drug_id': UUID('d2bc5d44-3a55-4d8e-8e04-a4cc39318709'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('c89ab7ee-3fb5-4e70-b817-46d035884316'),
#   'usage': 'CL5'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('37b4e564-6f6b-4de4-9c77-9f54d5537c64'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('5b5c4155-b2c0-4b9c-81f0-fd9cdd793db5'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('19acf24a-ac5b-44dd-b41b-d8bc83fcd1a4'),
#   'usage': 'CL6'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('7eb9ce6c-a0bb-4fc0-a1ca-df941d6f8a91'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('2a99b252-21a8-4dd5-aa8e-7cc18b1407ff'),
#   'usage': 'CL6'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('5617464c-3f09-4e6d-bb6e-409c4a49e715'),
#   'usage': 'CL3'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('a167d54f-7f07-44bf-b5ca-4ee5995697ac'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('98183169-efb0-43f0-b6fb-796e5cc3a6c8'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('7d692991-9d90-48fd-87f6-28c832d2c254'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('0762d2d5-3a35-4aba-8f22-93b580c50abe'),
#   'usage': 'CL3'},
#  {'patient_id': UUID('c3e0e113-153d-4c81-9664-5840804d5250'),
#   'drug_id': UUID('d2bc5d44-3a55-4d8e-8e04-a4cc39318709'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('0ba43691-a1da-4dca-aae5-681a2638cb48'),
#   'drug_id': UUID('c89ab7ee-3fb5-4e70-b817-46d035884316'),
#   'usage': 'CL6'},
#  {'patient_id': UUID('0ba43691-a1da-4dca-aae5-681a2638cb48'),
#   'drug_id': UUID('19acf24a-ac5b-44dd-b41b-d8bc83fcd1a4'),
#   'usage': 'CL6'},
#  {'patient_id': UUID('0ba43691-a1da-4dca-aae5-681a2638cb48'),
#   'drug_id': UUID('7eb9ce6c-a0bb-4fc0-a1ca-df941d6f8a91'),
#   'usage': 'CL3'},
#  {'patient_id': UUID('0ba43691-a1da-4dca-aae5-681a2638cb48'),
#   'drug_id': UUID('2a99b252-21a8-4dd5-aa8e-7cc18b1407ff'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('0ba43691-a1da-4dca-aae5-681a2638cb48'),
#   'drug_id': UUID('6aeba1fa-9fbc-4298-95d3-8ae55a19ac9a'),
#   'usage': 'CL1'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('c89ab7ee-3fb5-4e70-b817-46d035884316'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('98421806-3dcc-4aac-aff9-fab436d7a3f1'),
#   'usage': 'CL3'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('19acf24a-ac5b-44dd-b41b-d8bc83fcd1a4'),
#   'usage': 'CL5'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('7eb9ce6c-a0bb-4fc0-a1ca-df941d6f8a91'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('2a99b252-21a8-4dd5-aa8e-7cc18b1407ff'),
#   'usage': 'CL4'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('5617464c-3f09-4e6d-bb6e-409c4a49e715'),
#   'usage': 'CL2'},
#  {'patient_id': UUID('4aee56a6-538b-491b-98da-c31e36c67c7a'),
#   'drug_id': UUID('98183169-efb0-43f0-b6fb-796e5cc3a6c8'),
#   'usage': 'CL2'}]

# %% [markdown]
# ### patients_doctors_appointments

# %%
patients_doctors_appointments = []

start = date.today() - timedelta(days=random.randint(1, 365) + 365 * 9)
end = date.today() + timedelta(days=random.randint(1, 180))

dates = [start + timedelta(days=i) for i in range((end - start).days)]

# по воскресеньям не работает :)
dates = list(filter(lambda d: d.weekday() != 6, dates))

for working_date in dates:
    working_doctors_num = random.randint(5, 20)
    working_doctors = random.sample(doctors, working_doctors_num)
    for doctor in working_doctors:
        # если рабочие часы с 8 до 18, то максимум пациентов у доктора - 20
        patients_num = random.randint(10, 21)
        patients_with_appointment = random.sample(patients, patients_num)
        for i, patient in enumerate(patients_with_appointment):
            # работает с 8 утра, на каждого пациента полчаса
            appointment_datetime = datetime.combine(working_date, time(8, 0)) + timedelta(minutes=30) * i
            # консультация по записи не состоялась, если дата консультации позже чем сейчас, иначе состоялась с 70% вероятностью 
            is_committed = False if appointment_datetime > datetime.now() else  random.randint(1, 11) > 3
            patients_doctors_appointments.append({
                'id': uuid.uuid4(),
                'patient_id': patient['id'],
                'doctor_id': doctor['id'],
                'appointment_datetime': appointment_datetime,
                'is_committed': is_committed
            })
patients_doctors_appointments
# Out:
# [{'id': UUID('40f941bc-e30d-4a65-b18e-20312542f712'),
#   'patient_id': UUID('25712bdd-3ae9-4560-b8c2-7e80af4e18e8'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': False},
#  {'id': UUID('5d596330-974a-4e21-9aee-43b1da4a7cf7'),
#   'patient_id': UUID('1a3a5d8e-9e4a-4a5b-b6fc-48fba94e1012'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': True},
#  {'id': UUID('5ca82c4b-b2df-4a3b-9cfb-ee7942c54a2d'),
#   'patient_id': UUID('a87674e1-df20-4235-ab12-ee0995ddd3d7'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('5ddebac3-1442-4520-b72e-dd8297cd4ddf'),
#   'patient_id': UUID('bbaeb614-2c0e-4657-896d-71648d3bf274'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('83c51ceb-533c-4b8a-968a-49a8738cf0b7'),
#   'patient_id': UUID('6a16d3e4-febf-40d3-88e6-1870cf9a74cb'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': True},
#  {'id': UUID('d35d5a66-fa3e-4fd6-87ee-aef9fe1e84e9'),
#   'patient_id': UUID('07d2782b-e354-4165-a365-939c7f0103be'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': True},
#  {'id': UUID('05324721-b08e-4aa0-8030-4c8b18e21c32'),
#   'patient_id': UUID('729d6324-e791-4bb7-af6c-37505e8debef'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('d25e5ae2-b6bb-421e-9680-061f76c9e4dc'),
#   'patient_id': UUID('32454844-ab44-4f6b-bd29-6f428ea1fe84'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('59f650e7-0fc5-424a-ac76-4bb13d6b68fd'),
#   'patient_id': UUID('280c08a9-cec1-4d0d-8b6e-1b3dfc8a088b'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('68bdf985-947e-42ec-9e67-dee122b225f6'),
#   'patient_id': UUID('79817823-c7d7-4906-b5a6-0ff5c561e432'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('b2c9fe64-8eff-4025-928b-0f5e01149105'),
#   'patient_id': UUID('e3b9b2ba-a964-4980-a178-f96c044c21dc'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': True},
#  {'id': UUID('e35758d6-7e07-4c10-83be-d208567b4793'),
#   'patient_id': UUID('104b6d38-3faf-41f2-9f2b-fa611cc5fc98'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('b8ce39bb-cac5-4549-ad47-948726eb6fa7'),
#   'patient_id': UUID('4629a0c5-7f9a-4f60-96f6-adb31cfb28d7'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 0),
#   'is_committed': True},
#  {'id': UUID('32f0d390-1900-4c3d-b620-7ec6b6224105'),
#   'patient_id': UUID('a6f7eb22-236b-419e-802a-5588cf8edba8'),
#   'doctor_id': UUID('d15d8e83-ae44-4a15-8d81-aebb987fd772'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 30),
#   'is_committed': False},
#  {'id': UUID('ce1bbf21-7670-4f7b-9638-28a4378b9434'),
#   'patient_id': UUID('3ea4e275-580c-4eef-b903-38f4e0361ed2'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': True},
#  {'id': UUID('bf66dbff-1c73-4688-afb4-cbb6fee40d1a'),
#   'patient_id': UUID('66f4791b-3192-49a0-a2ef-cbd587d2b41e'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': True},
#  {'id': UUID('ba591c7a-b6b6-4ae4-9cca-83689d5034ca'),
#   'patient_id': UUID('80ac8cfb-cf76-44e4-a10f-8537f5f20339'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('4fb5dbba-5600-49ec-bb79-45f8d785f7d2'),
#   'patient_id': UUID('de266d7e-d8c2-492a-960f-38fdec2978b4'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('2711051e-0684-4821-917e-3e2b320b3c11'),
#   'patient_id': UUID('d72e2f49-2258-45da-b24e-93c107518bb8'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': False},
#  {'id': UUID('7f660deb-78ba-479c-bd9d-253982ee2f1e'),
#   'patient_id': UUID('c6f53341-6b5a-4a12-b248-0a4e9392a686'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': True},
#  {'id': UUID('4420144c-1158-455f-87fe-903baf474b64'),
#   'patient_id': UUID('64c0ca9d-8a12-42bf-9afc-8cf23adaf641'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('22840417-ff71-459c-b259-bbbccd43e083'),
#   'patient_id': UUID('2f304e5c-547b-4c40-af80-703350d1f881'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('9542e6dc-d0d0-4da7-8e01-040f9857642a'),
#   'patient_id': UUID('74c1f39e-41f0-4fda-a6dd-8e304a467598'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('8f37b6cb-32d5-4ec2-81f5-e4e678f55777'),
#   'patient_id': UUID('fb5a1767-fd37-4082-af40-db9e45e1789a'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': False},
#  {'id': UUID('14054be7-0eaf-4e09-8775-62857ad39394'),
#   'patient_id': UUID('decb1ad8-f0fd-4b0d-9a1b-5ca214a17b22'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': True},
#  {'id': UUID('cff80cf9-89a1-4c8b-92fd-bb206e9b9bd7'),
#   'patient_id': UUID('ecd7eebc-6c08-4b97-8fd5-5889ef189bf8'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('8c521ab2-2842-4179-a482-565494df394f'),
#   'patient_id': UUID('388eec11-7784-4c43-badc-de688e4a2acd'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 0),
#   'is_committed': True},
#  {'id': UUID('0569e523-4b4b-44d8-a906-a14fa58d9a8c'),
#   'patient_id': UUID('2fbaa96a-60c1-46ab-99ad-6c82f4f26176'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 30),
#   'is_committed': True},
#  {'id': UUID('ab6d8cab-974f-44d7-ac6d-e4e7cf4b684d'),
#   'patient_id': UUID('a768b2c6-3c05-42a6-9000-a7a7269120eb'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 0),
#   'is_committed': False},
#  {'id': UUID('0c997c8d-3506-4a77-90b7-ce80b0aae19e'),
#   'patient_id': UUID('67d2ae65-5234-446f-81dc-1c5476a78016'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 30),
#   'is_committed': True},
#  {'id': UUID('012eefea-e555-4250-b354-a40de8bb596e'),
#   'patient_id': UUID('8deccee8-1815-4445-9598-cd5bb36d2d9e'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 16, 0),
#   'is_committed': True},
#  {'id': UUID('6642322e-b205-4bbd-899e-9c7763ce3d34'),
#   'patient_id': UUID('6d2f6f6a-24f9-409a-994b-3793e9f65251'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 16, 30),
#   'is_committed': True},
#  {'id': UUID('b77601ef-b254-4fe8-8ca9-7c64408fa6b5'),
#   'patient_id': UUID('b1f2c513-a400-4fb8-a062-8f69ee0a55e2'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 17, 0),
#   'is_committed': True},
#  {'id': UUID('265bfa72-f7a8-49f3-a880-469e46af633f'),
#   'patient_id': UUID('c97f16eb-5f88-4aeb-aa37-e8fa952be74f'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': True},
#  {'id': UUID('4e616254-4728-4983-b55f-a8c0505f5b94'),
#   'patient_id': UUID('8a2aee41-66f5-4816-9a09-797fd0b16df9'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': False},
#  {'id': UUID('bb2c6295-0c0b-41b1-bcfa-73233e6e9dbc'),
#   'patient_id': UUID('c32aea3b-3b88-4ce7-b97f-f0800363f46d'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('8482767e-c7e9-450f-be79-b1bc8d8e5f10'),
#   'patient_id': UUID('8f4c5043-ee79-4a1c-8e0a-1da83b5182de'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('829edec8-3bd5-483d-84dc-990652787cba'),
#   'patient_id': UUID('d677d4cf-f51c-4edc-b12a-0352704ef647'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': False},
#  {'id': UUID('ab5b6757-4874-430e-acd3-f1e240ccaa8a'),
#   'patient_id': UUID('6018a753-753c-4f48-9a47-819967796cc5'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': False},
#  {'id': UUID('0cc42c49-ee99-4665-ada9-25ff36f5f6f0'),
#   'patient_id': UUID('41c31079-1a8a-415a-bcc0-fd6a9b268c28'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('d1ac76c3-3fc4-4556-ab8d-f4a53f1e0e26'),
#   'patient_id': UUID('1ccc64d6-7114-4d0f-84b0-765d0e65326f'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': False},
#  {'id': UUID('1dbe6a06-8dad-4e4c-9cca-8e75cd161f47'),
#   'patient_id': UUID('a402fd3e-c98f-46c5-9b7e-0fc35bd4880c'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('65dd0861-d6e5-4c94-86e8-0de0662e736e'),
#   'patient_id': UUID('aff81c76-0e04-4bdf-b248-56508a7780fb'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('ac30842f-91d8-4100-97d2-bddb36c825fd'),
#   'patient_id': UUID('df887382-0bf2-4fc8-85e4-235d2eebf121'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': True},
#  {'id': UUID('dbd3ee0a-fd17-499e-b1de-22f75a910acd'),
#   'patient_id': UUID('1228dcc3-543e-4b14-bb47-9faa3deb1550'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': True},
#  {'id': UUID('3298af51-db1e-44d9-895a-44ca3a2a06e1'),
#   'patient_id': UUID('240a5e71-24b4-4756-970a-bb3ab1d78304'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('011e104b-2027-46b3-a650-a567501485f8'),
#   'patient_id': UUID('20983ff4-5d71-44f1-a7e2-d36d93260ece'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('b0bb3f50-0767-4333-b4a6-5aa10eb4c6b5'),
#   'patient_id': UUID('30ed29bf-0bdb-41b7-a994-50e286f9cf63'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': False},
#  {'id': UUID('d48ff6ce-7564-4704-90c7-9841dacc027f'),
#   'patient_id': UUID('56a59394-53b2-41ce-baa6-0529f119c275'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': True},
#  {'id': UUID('f71ec519-a7ce-4685-94fb-62bc446fb1eb'),
#   'patient_id': UUID('fdd3703d-268d-46cb-85de-84d252ecd805'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('072e0989-8527-4bab-9630-4dd56f702abb'),
#   'patient_id': UUID('783a04de-1f55-4842-a998-66358fe4b318'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('32be70cc-4f2f-4a60-9e16-305da9624e6e'),
#   'patient_id': UUID('fcd548d1-37fb-4b0a-8515-9816112adc6a'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('9881901c-82bf-447d-92b8-2bdc98b839ca'),
#   'patient_id': UUID('06e5c4dd-b5d6-42c7-8be2-824469c4ac02'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('b7850446-e16c-410b-b4bc-b15d9e6d44ee'),
#   'patient_id': UUID('d0dcfc84-5d56-42f7-b663-4c61844dd782'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': True},
#  {'id': UUID('a0ed6adb-a84b-4b70-b04a-0d61aff47c7d'),
#   'patient_id': UUID('44b329dd-c2f4-4aa4-9c76-7867f7c1f027'),
#   'doctor_id': UUID('138dc388-5bb2-4117-980c-dcf318e64755'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('3012e8f1-2513-4da3-8695-496d7a82870e'),
#   'patient_id': UUID('59688de2-d4b6-4321-9e72-f3ebbbf188da'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': False},
#  {'id': UUID('973b0fa8-58eb-47eb-903b-19cc01743b3f'),
#   'patient_id': UUID('43bdc253-5913-4255-bf57-b8bd7ff36a16'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': False},
#  {'id': UUID('5b01a4e7-b207-43c1-96ba-804ce02afb98'),
#   'patient_id': UUID('a82d9d9d-e42a-4214-866e-c11f2bd7d089'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('ca2fad68-bfba-4363-9988-4568ff4d2545'),
#   'patient_id': UUID('070dbc81-b3b9-4320-9bec-fdda6338dfb4'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': False},
#  {'id': UUID('ef915b92-d4fc-41db-b533-ca80992d827a'),
#   'patient_id': UUID('5c82a283-8f63-4118-9ab5-f562499aac34'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': True},
#  {'id': UUID('83849a00-ec2f-4464-9004-b7952a2fe55d'),
#   'patient_id': UUID('8c399840-1a33-4360-a05c-d4b2e8c044a4'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': False},
#  {'id': UUID('692cc3a9-df0a-4a33-8b0a-e31dcf43a022'),
#   'patient_id': UUID('d231d337-cba4-494c-b480-f804eea62f9d'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': False},
#  {'id': UUID('aab9a9cd-cfaf-41ee-8f3e-46a2bbd8428c'),
#   'patient_id': UUID('a35157f4-130e-4ad4-a9f8-06221ce9b21b'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('a598c4b0-99ab-429e-bae9-a442fa668dcc'),
#   'patient_id': UUID('aa0d3ab0-437e-4c5e-b94d-ff7b6b7d1914'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('f9e2c18c-d79e-4ec7-bd64-29af94f23bb2'),
#   'patient_id': UUID('1a6c9dfe-208d-459d-b742-3dbb4ef93b16'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('cbf94939-7671-4b3b-95fb-37654f9b9154'),
#   'patient_id': UUID('1a1ae00b-ac49-4235-952c-377d0fa0382e'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': False},
#  {'id': UUID('18661e8f-f0f1-4f9f-bb00-7df4dce34647'),
#   'patient_id': UUID('96cef089-6361-4fab-99d6-73a3d02877a2'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('763db072-e7e7-4a0a-8b57-23f7f6f76df8'),
#   'patient_id': UUID('1d88ecb4-5f0b-446a-b928-892af4f6bbc5'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 0),
#   'is_committed': True},
#  {'id': UUID('184093cc-849d-410b-be2a-6a19a3bb5fbd'),
#   'patient_id': UUID('949e7fe9-b25f-4067-bc15-e9ccad49914b'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 30),
#   'is_committed': True},
#  {'id': UUID('ab8caed9-39fc-43fe-ad77-e91e5d14f7f6'),
#   'patient_id': UUID('5922823e-ef11-45de-b3b9-d8cd49bac57f'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 0),
#   'is_committed': False},
#  {'id': UUID('2d36cdf0-b51f-4089-bac2-b13b444dacb2'),
#   'patient_id': UUID('20ae21d4-75ee-477d-848e-d8bd0a831382'),
#   'doctor_id': UUID('75d50f50-04ed-43c3-9474-137c8037c45e'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 30),
#   'is_committed': True},
#  {'id': UUID('79bc96d7-c205-4a1d-8fe3-c1191b30444c'),
#   'patient_id': UUID('7666d2f6-c605-473d-95b0-c4657d32585b'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': True},
#  {'id': UUID('3be731f6-ddfc-49a7-ad0f-783cc537cfdd'),
#   'patient_id': UUID('949e7fe9-b25f-4067-bc15-e9ccad49914b'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': True},
#  {'id': UUID('ec4a6a16-a02a-4fa7-bee4-1842a40e2eaa'),
#   'patient_id': UUID('796fdf20-cdf6-4609-9eec-dea8fdbf4134'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('60339f55-887f-4dcd-982b-f33a8bfb4978'),
#   'patient_id': UUID('8e047bb9-f228-4228-a1ea-e48fe1ec5ff7'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('ccd4eed1-d7b9-4bb5-a37a-00b4d237001b'),
#   'patient_id': UUID('a9281afe-5ead-484c-84cd-a340ec228bfb'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': False},
#  {'id': UUID('67145385-8ba1-41b1-bd31-0d03ae66378e'),
#   'patient_id': UUID('b32ad44e-a337-40af-9d39-2d855734644f'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': False},
#  {'id': UUID('2ab6889c-1834-4136-b8f5-3f18b9595e35'),
#   'patient_id': UUID('1076eec7-bb09-4bbb-b5ef-f80abdf0eb5b'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('6222d75a-6a06-44c1-9494-351f254d141a'),
#   'patient_id': UUID('39b9e4a0-96fe-4d53-b1c2-e7c20169a9c3'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('4d489cbf-3ed3-4321-a89f-81d21304ba40'),
#   'patient_id': UUID('d7c9f573-7eca-4a92-9cb4-e89b90cd7b00'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('118c7f44-3cdf-44e0-a3fc-2a134c8ba81a'),
#   'patient_id': UUID('77a509e3-f323-4652-a329-d76c45614139'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('3b9e9235-f600-4541-a731-5882bf9d5ac7'),
#   'patient_id': UUID('98b7dba2-8b5d-4c20-9563-66d813763af2'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': False},
#  {'id': UUID('144ff32f-bc12-4a96-9824-f69c908eb99d'),
#   'patient_id': UUID('92305cf3-509a-4a9b-99ac-ce1ebb9345a7'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('de53ac4a-2f97-4ea1-9cb7-a5d77295c234'),
#   'patient_id': UUID('50f3cbe1-bba0-4969-9d10-e51e1d1d9fb3'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 0),
#   'is_committed': False},
#  {'id': UUID('dab5a30f-73cb-41e8-be19-39d8ab343e5e'),
#   'patient_id': UUID('0e50a419-0979-4e6a-9ced-d97f4cb2aafc'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 30),
#   'is_committed': True},
#  {'id': UUID('066bc932-9f93-4de5-8c49-f67f2c4a31ff'),
#   'patient_id': UUID('11a9e8f9-3211-4445-ac92-6982d6d652e1'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 0),
#   'is_committed': True},
#  {'id': UUID('3a76248f-7948-41ec-b254-87fa8d8d50f2'),
#   'patient_id': UUID('0c6ecf51-2abe-4892-8e23-da202452b8f8'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 15, 30),
#   'is_committed': True},
#  {'id': UUID('f614e7e4-6cb7-47af-905d-0489df15b26c'),
#   'patient_id': UUID('bb8a4522-35ae-4b80-9284-b7c93507feff'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 16, 0),
#   'is_committed': True},
#  {'id': UUID('990dd213-2116-4931-9234-41262ef25bb3'),
#   'patient_id': UUID('78a6bba8-c6b9-4e97-b0a5-73195a8191e3'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 16, 30),
#   'is_committed': True},
#  {'id': UUID('633d2ee2-5088-4cb1-9d1e-d047ba5bcd70'),
#   'patient_id': UUID('da7babbc-23be-4e07-b6f4-b0904dafb151'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 17, 0),
#   'is_committed': True},
#  {'id': UUID('c503fe76-5bd3-4e4d-9e63-e9e25247eb0d'),
#   'patient_id': UUID('b2796573-f8f9-4ec8-bae1-71bc2fb4d6a0'),
#   'doctor_id': UUID('7f18cef6-388c-48c4-b500-014f5fcb87fd'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 17, 30),
#   'is_committed': True},
#  {'id': UUID('da7ed11e-2e21-437a-81dd-aa17e4f465ee'),
#   'patient_id': UUID('1748412d-a239-4c17-a838-17c773f002ba'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': False},
#  {'id': UUID('cb54388f-a38f-4e5c-b538-423c5fc8f22b'),
#   'patient_id': UUID('42dffb73-4b62-4dc9-afc7-35f3b7eb9bb9'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': False},
#  {'id': UUID('5f24abf9-0546-4f43-93cb-4e6602baeb2c'),
#   'patient_id': UUID('42d994bd-1944-4b4e-ab51-6c6059dcbc6a'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('2e86bf2d-f20c-4d56-914a-d7787c908eab'),
#   'patient_id': UUID('f0b414ae-4aba-41bd-8295-a1aaeadca575'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': True},
#  {'id': UUID('96f89a7b-18dd-45b2-8260-040e29f9cc52'),
#   'patient_id': UUID('46ae5e3a-20e1-497b-91fa-e3260334dfa7'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': True},
#  {'id': UUID('e946263a-a3f0-476c-b573-3b1939294587'),
#   'patient_id': UUID('cb854b5f-3849-4a17-a01d-c2b53c7a386e'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': True},
#  {'id': UUID('177bee1f-099d-4588-b17b-33b0228c449a'),
#   'patient_id': UUID('e14c89bc-a972-457d-a8e7-825168cd87e3'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('6545f997-3e8c-4b03-a19c-574be4f1f31f'),
#   'patient_id': UUID('f7b540a5-ab9e-4b3a-b454-c9248a017a0b'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('bec4bd80-e2e2-47cd-97f5-29eb36e3e45c'),
#   'patient_id': UUID('35d7bbbb-01f0-4dda-841f-7ba4d4265a9b'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': False},
#  {'id': UUID('79f81ac8-d0e4-4229-8c36-f4a4e395c6bc'),
#   'patient_id': UUID('e60a9012-dd24-459a-a399-68894d04244a'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('4cc55703-d257-47a8-a927-90bf6b44a03a'),
#   'patient_id': UUID('7cd48d29-cc81-467d-9098-d40e842fe7e6'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': True},
#  {'id': UUID('7183e6ac-ac31-477e-9652-812e0a40ba90'),
#   'patient_id': UUID('f9a1ba40-2ff3-49a0-b689-675dccba750b'),
#   'doctor_id': UUID('1219742c-f085-46fe-befa-b9623832dbbf'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('8f2fe6f0-68a8-43ab-8457-4aaae644bb10'),
#   'patient_id': UUID('2c4c009d-ee63-47c2-bc8b-a184232f0939'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 0),
#   'is_committed': True},
#  {'id': UUID('3cb9c085-7fd3-4d5e-95fb-8fb2862c7b5d'),
#   'patient_id': UUID('69900b3d-e3d5-4bf0-99e1-156a9498227f'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 8, 30),
#   'is_committed': True},
#  {'id': UUID('b5f2fc55-a486-470c-8564-86c47dba781c'),
#   'patient_id': UUID('4eb0e06d-fe6d-46d4-9bd4-752676cd80c6'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 0),
#   'is_committed': True},
#  {'id': UUID('fc7013f3-160c-46c0-88e9-0ea4ac789970'),
#   'patient_id': UUID('cb4d5934-fda7-4ca1-b249-14ae1d5ceb85'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 9, 30),
#   'is_committed': False},
#  {'id': UUID('e2f7afcd-e65f-41d3-904e-802b9354c5d4'),
#   'patient_id': UUID('d234e3dc-ea3c-410f-bee8-3316744004ba'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 0),
#   'is_committed': True},
#  {'id': UUID('d1166d37-2ab8-432d-b370-6096f7a2faed'),
#   'patient_id': UUID('afd6df28-f43a-476c-b57b-a4b5040feecc'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 10, 30),
#   'is_committed': True},
#  {'id': UUID('49bc7b92-1408-4d50-8895-4369662519c6'),
#   'patient_id': UUID('823976f3-42e6-4a8e-ab76-70bb1666d567'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 0),
#   'is_committed': True},
#  {'id': UUID('7642e7a2-f9b3-49ce-92e0-14c5883c4d57'),
#   'patient_id': UUID('4df08ff2-bbe5-4fb2-8609-d0294e448c85'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 11, 30),
#   'is_committed': True},
#  {'id': UUID('941eda0f-c7b8-4d4b-bfc5-c7221c590087'),
#   'patient_id': UUID('283d3336-36e1-4f69-a50d-8011ca9823d2'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 0),
#   'is_committed': True},
#  {'id': UUID('c9f63b7f-3830-4923-8fd6-879abb5780d3'),
#   'patient_id': UUID('2269b208-7ef2-4ecd-afc0-2b2fa34d1669'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 12, 30),
#   'is_committed': True},
#  {'id': UUID('2ad9162f-18cd-41f4-8c70-db033fb1be93'),
#   'patient_id': UUID('e17c91ac-4d1b-4fb3-92b0-b8748159f58c'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 0),
#   'is_committed': True},
#  {'id': UUID('6610d30e-b4a1-42a0-8809-eae8580c22e5'),
#   'patient_id': UUID('0f3fca79-6a53-4315-b2c7-6aec70f28512'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 13, 30),
#   'is_committed': True},
#  {'id': UUID('c95be85d-121b-4950-9bfa-61d41dd32534'),
#   'patient_id': UUID('7b7495d4-49a0-4427-89f4-1d3ea927b2a7'),
#   'doctor_id': UUID('775cc3e6-a4a6-4ea0-8442-c700931f3df7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 7, 14, 0),
#   'is_committed': True},
#  {'id': UUID('c2ae8a7d-db61-4351-8aa8-98de153c7f0c'),
#   'patient_id': UUID('c5edf9a7-3031-4330-b110-656ce440c2d1'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 0),
#   'is_committed': True},
#  {'id': UUID('c2ae35a7-ae32-4328-bc27-54b94840af54'),
#   'patient_id': UUID('ba30a0b2-e9a4-4312-ab84-b512d88196e7'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 30),
#   'is_committed': False},
#  {'id': UUID('adad90a4-06e3-4a6c-813e-d0cbe893a9e4'),
#   'patient_id': UUID('7f894483-0365-4ef1-bd16-a7c8ab8028a4'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 0),
#   'is_committed': True},
#  {'id': UUID('eb9ad42f-c689-418c-83b3-5faed78fa69e'),
#   'patient_id': UUID('cfc5ac33-2c13-4e64-a937-af1e57e86e1b'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 30),
#   'is_committed': False},
#  {'id': UUID('257a1b73-24b5-4f3d-b2ac-8b142f9f48da'),
#   'patient_id': UUID('dde15f59-746f-4cd7-ac6e-8fd2a0473284'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 0),
#   'is_committed': False},
#  {'id': UUID('340f7e72-b3aa-4d9c-af22-308843df4123'),
#   'patient_id': UUID('c5ff594b-28cd-402a-af25-40126f811a2a'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 30),
#   'is_committed': True},
#  {'id': UUID('c7c4617b-2f6e-4de6-a619-22ab224ad5a5'),
#   'patient_id': UUID('a9abdde1-62c5-4615-b053-f63468a46f3a'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 0),
#   'is_committed': True},
#  {'id': UUID('41d8fb30-e92a-49d6-8735-dbb49ef87055'),
#   'patient_id': UUID('ecf1bd3d-62be-4857-9748-450e272a5b9c'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 30),
#   'is_committed': True},
#  {'id': UUID('b5745da9-2a96-46a2-aee4-cd127c5d12c2'),
#   'patient_id': UUID('f0b414ae-4aba-41bd-8295-a1aaeadca575'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 0),
#   'is_committed': True},
#  {'id': UUID('74d363c0-b20c-40d9-924d-dc439e0adc4e'),
#   'patient_id': UUID('baec9d4b-d28a-4e44-8d59-18990b39a72d'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 30),
#   'is_committed': False},
#  {'id': UUID('ac1e6842-59ee-4849-87c3-bd355108b063'),
#   'patient_id': UUID('5e6efa8d-be5e-4d00-94cf-46954be2cf29'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 0),
#   'is_committed': False},
#  {'id': UUID('3423ddfd-2c57-4012-91d7-b3ba52f6907d'),
#   'patient_id': UUID('6285fd4b-e970-437c-9dbc-04e08bce4dbd'),
#   'doctor_id': UUID('2898e220-4942-4a76-9441-7b9d39bae614'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 30),
#   'is_committed': True},
#  {'id': UUID('0917d25f-2f38-491d-aef3-089f99459095'),
#   'patient_id': UUID('c32aea3b-3b88-4ce7-b97f-f0800363f46d'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 0),
#   'is_committed': False},
#  {'id': UUID('7f7bad07-2e02-4572-b7fc-f71b37cb333d'),
#   'patient_id': UUID('9f7f0dd6-8314-4da2-bb22-76e21f052fb3'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 30),
#   'is_committed': True},
#  {'id': UUID('67e12520-ad0c-4a7e-a1ec-7bd03a4dd650'),
#   'patient_id': UUID('35a420b6-5cea-419e-9b18-7e44414d8e48'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 0),
#   'is_committed': True},
#  {'id': UUID('a103d66f-cc97-4df7-a7f8-0ef326e5ac53'),
#   'patient_id': UUID('a7679312-a6a7-460b-ae82-c0c717a14d8d'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 30),
#   'is_committed': True},
#  {'id': UUID('7e3a1962-65cf-49c1-b473-027d35937c51'),
#   'patient_id': UUID('7cb85b50-bf46-4501-82c0-1b10673288c8'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 0),
#   'is_committed': True},
#  {'id': UUID('022d8df7-d065-4d2e-b608-30f1a3ef34ed'),
#   'patient_id': UUID('100bb2c7-1ffc-44aa-9fbe-65178b1114ef'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 30),
#   'is_committed': False},
#  {'id': UUID('60ffee96-05bd-4753-b157-48a9abe5dd9b'),
#   'patient_id': UUID('f48a9c27-0cbf-49b4-8cf3-79bd13c0cd87'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 0),
#   'is_committed': True},
#  {'id': UUID('ee702a82-2702-4bdc-9a77-13d05154d6e4'),
#   'patient_id': UUID('485ba85b-a9fd-434e-ba13-a4ba6589e3aa'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 30),
#   'is_committed': True},
#  {'id': UUID('7ae5364f-d657-4cc1-b249-eff4a8605c2e'),
#   'patient_id': UUID('a0e20d97-abfb-4a9f-b3b3-f9bf59ee2e5c'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 0),
#   'is_committed': True},
#  {'id': UUID('cad6eeb8-baa7-4c71-ad34-3ba342d44077'),
#   'patient_id': UUID('9f722f3b-95cf-4bbe-8013-a5c56dc396cc'),
#   'doctor_id': UUID('c929de26-f7a7-46b1-9ff7-345cc74a23e7'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 30),
#   'is_committed': True},
#  {'id': UUID('5ae6e324-333d-4cd0-835d-dcb512032fd1'),
#   'patient_id': UUID('9ff0fe00-c359-4f2c-9062-26e5734aaac3'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 0),
#   'is_committed': True},
#  {'id': UUID('0349abba-b9cb-46c6-83ba-03fa75dcce5b'),
#   'patient_id': UUID('bb801080-352f-4ef6-81e6-1f9d6d878218'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 30),
#   'is_committed': True},
#  {'id': UUID('763116c8-0517-4c7f-a70e-19671aa58b1a'),
#   'patient_id': UUID('07643c6d-e087-45d3-83af-0c71b4d89c91'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 0),
#   'is_committed': False},
#  {'id': UUID('7eece6c9-cb18-487b-9ead-12116ce38a71'),
#   'patient_id': UUID('5820a2cd-ab39-452c-b195-bf5e5b5f7e7d'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 30),
#   'is_committed': True},
#  {'id': UUID('5a0bfdf7-d828-44cb-a8c8-6e4b6eb37940'),
#   'patient_id': UUID('bfe5fe95-c4ef-4e08-8d4d-2e8e86a534a6'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 0),
#   'is_committed': True},
#  {'id': UUID('3c855ff8-c6cb-4f85-bd98-9bb7dc42c574'),
#   'patient_id': UUID('88d0f180-1691-4091-8a45-eb8345c07bb3'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 30),
#   'is_committed': True},
#  {'id': UUID('cb82657b-b784-4c47-aba6-e361097e2268'),
#   'patient_id': UUID('70190d4a-74da-4c17-9d90-c252ee36de65'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 0),
#   'is_committed': True},
#  {'id': UUID('9c02021c-6dc9-4138-a1f3-c8a35cb73755'),
#   'patient_id': UUID('10dcf972-87be-41c2-aaea-20792a38df90'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 30),
#   'is_committed': True},
#  {'id': UUID('b19166fe-5f0a-406a-9ef8-e13578e26a15'),
#   'patient_id': UUID('491c2373-d214-4083-b42b-1ff575d9c9e1'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 0),
#   'is_committed': False},
#  {'id': UUID('99fc9e03-917f-49ac-8512-ef49378e7090'),
#   'patient_id': UUID('1748412d-a239-4c17-a838-17c773f002ba'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 30),
#   'is_committed': True},
#  {'id': UUID('de207030-38e7-4cdd-972b-0ed1aa6bf0a3'),
#   'patient_id': UUID('00b01919-2ff3-4728-93b6-52da028f891e'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 0),
#   'is_committed': True},
#  {'id': UUID('1630bdad-3c0b-4246-9660-2ded38abc7f3'),
#   'patient_id': UUID('fdd3703d-268d-46cb-85de-84d252ecd805'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 30),
#   'is_committed': True},
#  {'id': UUID('0a046d94-52b0-43e6-8057-88f3f29d817b'),
#   'patient_id': UUID('23fc3dab-2ab5-4ffc-b3c2-3a3f9f040607'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 14, 0),
#   'is_committed': True},
#  {'id': UUID('71197991-1f39-4846-a8d3-00739ec8b3e3'),
#   'patient_id': UUID('6988e8ae-f1c0-4bc5-ae9c-a3049e525b77'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 14, 30),
#   'is_committed': True},
#  {'id': UUID('4d411d1f-6718-4e00-a663-6c507f63a0eb'),
#   'patient_id': UUID('fde7a387-471c-48e2-b8a7-d1e1094c4e51'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 15, 0),
#   'is_committed': True},
#  {'id': UUID('a1e034d6-057d-48ea-9ced-00bacb42068d'),
#   'patient_id': UUID('9742bca6-cef8-484d-8949-53f157bd61c9'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 15, 30),
#   'is_committed': True},
#  {'id': UUID('827db622-d3c4-4183-b500-762aa6a4e0c3'),
#   'patient_id': UUID('70e77e94-8b8f-4da0-bc92-b5ee08180862'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 16, 0),
#   'is_committed': True},
#  {'id': UUID('ddaaf8c2-4417-44b6-921e-37faf7752a5d'),
#   'patient_id': UUID('4bea1cbd-7e27-4969-9b97-7fa5f342f27b'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 16, 30),
#   'is_committed': True},
#  {'id': UUID('4e912d81-5b67-478b-a035-e0833266b880'),
#   'patient_id': UUID('ea7df0a1-c9c8-44f2-b0ee-1dd08420f071'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 17, 0),
#   'is_committed': True},
#  {'id': UUID('0d28eaa8-e6e2-4327-b79b-3515990d2273'),
#   'patient_id': UUID('9024dc21-aeb4-4c6b-ba1e-0da7ef4ac435'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 17, 30),
#   'is_committed': True},
#  {'id': UUID('0853bb74-cb66-43fe-b0fd-107e3384ff62'),
#   'patient_id': UUID('162efc59-ed03-4acf-86d1-3c376c0f1f60'),
#   'doctor_id': UUID('7dd433de-57b5-4f94-a57c-9c54b053f54b'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 18, 0),
#   'is_committed': True},
#  {'id': UUID('7c13e93d-c31c-45d3-a781-8d8adbe513e9'),
#   'patient_id': UUID('a015cbce-c22d-4538-ab25-4ec395840252'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 0),
#   'is_committed': False},
#  {'id': UUID('c72d2226-f7ae-4265-bf73-cb3431b4b1b4'),
#   'patient_id': UUID('8dfe78ea-321c-4aff-bac8-85b3cc4d6a69'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 30),
#   'is_committed': True},
#  {'id': UUID('f940bd03-613b-4590-9005-17b97dc3d9ce'),
#   'patient_id': UUID('fbd5f2fb-3d30-42f2-87b5-0d46e6089c4e'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 0),
#   'is_committed': True},
#  {'id': UUID('e8c2c1ed-1349-4603-b984-b3675fc3e977'),
#   'patient_id': UUID('6263f19c-b17e-413e-8057-2bc2ef1a31ea'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 9, 30),
#   'is_committed': True},
#  {'id': UUID('fca76149-29bf-4689-bb1b-bd1944e6bf9e'),
#   'patient_id': UUID('796fdf20-cdf6-4609-9eec-dea8fdbf4134'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 0),
#   'is_committed': False},
#  {'id': UUID('d24d3706-f684-4c95-ad87-7312afa5767d'),
#   'patient_id': UUID('1cf68c64-9827-4542-88f6-d5a878473f3e'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 10, 30),
#   'is_committed': True},
#  {'id': UUID('66c280d4-afad-4a12-a2e3-256f85685930'),
#   'patient_id': UUID('4a3b408c-e180-49af-a69c-9fc16d3d85d2'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 0),
#   'is_committed': False},
#  {'id': UUID('1c1e0977-870c-4f9c-8f5d-0fe2d782087a'),
#   'patient_id': UUID('45a2ad13-067f-440f-907d-3aff1c10feae'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 11, 30),
#   'is_committed': True},
#  {'id': UUID('57407e54-f6f3-42cd-b587-a2ac8f904fb6'),
#   'patient_id': UUID('c5ff594b-28cd-402a-af25-40126f811a2a'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 0),
#   'is_committed': False},
#  {'id': UUID('0c7603ee-5277-4e3c-9316-44664d2a5aa6'),
#   'patient_id': UUID('fe078118-ee55-4469-a163-b0811f65b717'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 12, 30),
#   'is_committed': False},
#  {'id': UUID('ea64d5ee-5ab0-4a2b-9e1d-d7b7fa03df5b'),
#   'patient_id': UUID('aadad12e-a974-4fb5-a2e0-53ad489db516'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 0),
#   'is_committed': True},
#  {'id': UUID('69a82831-2d13-48db-bc12-020af8af5a78'),
#   'patient_id': UUID('82ee7e62-54ff-4751-b200-2d41aee97a3b'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 13, 30),
#   'is_committed': True},
#  {'id': UUID('6cc5fe33-b6f1-4682-93a6-df8f00285ad0'),
#   'patient_id': UUID('538fcf1f-feac-401a-812a-affdb1788dbe'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 14, 0),
#   'is_committed': True},
#  {'id': UUID('26f81c3b-c797-429b-b43b-8dfe47700615'),
#   'patient_id': UUID('199c1495-4071-44b8-90a3-1b757faac15d'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 14, 30),
#   'is_committed': True},
#  {'id': UUID('1ba314a1-ea38-4a52-af54-93b4accc0123'),
#   'patient_id': UUID('5e52d45f-e7ba-4417-8edb-efb82afaf34b'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 15, 0),
#   'is_committed': True},
#  {'id': UUID('23b9b45b-a0e2-444f-9c36-684d13217996'),
#   'patient_id': UUID('8bfe81e1-8323-437a-84d9-a9088a4b4c3c'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 15, 30),
#   'is_committed': True},
#  {'id': UUID('d334ad6a-e836-44a3-9b41-fcd4067277bb'),
#   'patient_id': UUID('d8dfc4ec-ecdd-4db3-858a-6bfb72b76844'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 16, 0),
#   'is_committed': True},
#  {'id': UUID('02f91928-a083-4f6b-ba79-fbae7056a397'),
#   'patient_id': UUID('e63f4fe4-0564-420f-ac10-cd646f1c7e3d'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 16, 30),
#   'is_committed': True},
#  {'id': UUID('5e00fe75-2409-4442-8ccf-5b38a1d39a1b'),
#   'patient_id': UUID('edc45bd7-88b2-4788-950c-ae4f7f54cd74'),
#   'doctor_id': UUID('ea92442b-a330-4fb4-851b-4e8bd2508211'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 17, 0),
#   'is_committed': False},
#  {'id': UUID('bf8cb441-733c-4395-b803-6c9b61bfcf59'),
#   'patient_id': UUID('03ead51f-2b33-4438-8bdb-00f2e08f3dfd'),
#   'doctor_id': UUID('4d889b21-a337-4d39-9eaa-f2f263432d88'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 0),
#   'is_committed': True},
#  {'id': UUID('755463bb-8dba-4dbe-9aab-c4439fc8e67a'),
#   'patient_id': UUID('0373acfd-da11-4ee3-81a9-db2f52a22c71'),
#   'doctor_id': UUID('4d889b21-a337-4d39-9eaa-f2f263432d88'),
#   'appointment_datetime': datetime.datetime(2015, 3, 9, 8, 30),
#   'is_committed': True},
# ...
#   'patient_id': UUID('8f4c5043-ee79-4a1c-8e0a-1da83b5182de'),
#   'doctor_id': UUID('a8b7ea59-e00e-47b5-a44e-91be7c2bc4f2'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 14, 0),
#   'is_committed': True},
#  {'id': UUID('03a8e2bd-ba9e-45c2-9045-3099df0856d2'),
#   'patient_id': UUID('cd434c88-dfc3-492c-acf5-86bc00a56259'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 8, 0),
#   'is_committed': False},
#  {'id': UUID('70d8c584-eecf-43c9-b7bc-33f42630bc45'),
#   'patient_id': UUID('24fd5a87-d0b3-49d2-a329-d9a9b3d13ab6'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 8, 30),
#   'is_committed': False},
#  {'id': UUID('fac6e356-92c1-400d-884f-a2c2e304c9c2'),
#   'patient_id': UUID('d9a90120-fbc2-411f-868f-2d5019fc46ae'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 9, 0),
#   'is_committed': False},
#  {'id': UUID('409583f4-81eb-437c-92e4-cfbda31927a0'),
#   'patient_id': UUID('71952177-08eb-4337-b652-b2901df084c1'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 9, 30),
#   'is_committed': True},
#  {'id': UUID('48509233-727a-41fe-bd71-f7b424628f81'),
#   'patient_id': UUID('b3ee3860-4ea4-4f57-95f8-88951b713c52'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 10, 0),
#   'is_committed': True},
#  {'id': UUID('841902a1-a410-4d04-bd43-672fde0f0aa5'),
#   'patient_id': UUID('9eef90be-7fc9-470d-b6c1-c8f50e4696b9'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 10, 30),
#   'is_committed': True},
#  {'id': UUID('de26f2a2-823c-4d89-acc2-1f0c4c598671'),
#   'patient_id': UUID('84e282c2-6f30-455f-81bc-d4c5b9ba259e'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 11, 0),
#   'is_committed': True},
#  {'id': UUID('beddf77d-3622-4783-a23f-25d0b462fa9d'),
#   'patient_id': UUID('fdd3703d-268d-46cb-85de-84d252ecd805'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 11, 30),
#   'is_committed': True},
#  {'id': UUID('7a28533d-84b0-4e8d-876c-7e42afac4b35'),
#   'patient_id': UUID('afd08eb9-1947-4076-a7f5-7be83c2d16b2'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 12, 0),
#   'is_committed': False},
#  {'id': UUID('0810cff5-1c74-4944-afca-f571e47a0a4a'),
#   'patient_id': UUID('a3e6e092-9a13-407c-888f-76c2a46186dc'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 12, 30),
#   'is_committed': True},
#  {'id': UUID('d9be9465-2e71-4669-b780-a22416c1a0c0'),
#   'patient_id': UUID('af41faee-cfd1-40c2-9ca6-3f9ce5df10f9'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 13, 0),
#   'is_committed': False},
#  {'id': UUID('1230a094-ebde-4e4a-8222-b450a17a472c'),
#   'patient_id': UUID('f5f68326-1ea7-4d8d-8bea-eea95e808817'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 13, 30),
#   'is_committed': True},
#  {'id': UUID('f872ac51-6c0f-4940-bf27-89c829df84e9'),
#   'patient_id': UUID('8b313221-7030-4714-bc25-ffd9db9c614f'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 14, 0),
#   'is_committed': True},
#  {'id': UUID('6848d2b5-6d0a-40ed-bc6b-f2063bce36e9'),
#   'patient_id': UUID('b97bd69d-bfd2-4331-91a3-b7126e2b3568'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 14, 30),
#   'is_committed': True},
#  {'id': UUID('2d2e1c85-2083-426c-810f-b31b6ab64df2'),
#   'patient_id': UUID('7b7df6b7-6869-454d-a544-653a4312856f'),
#   'doctor_id': UUID('9ba963f5-daca-43e2-8d28-e0cc34caee9c'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 15, 0),
#   'is_committed': True},
#  {'id': UUID('0a682eaf-bc67-489b-bb73-ec79c9cbcc61'),
#   'patient_id': UUID('2444285c-9585-4d7a-aa7d-d39563830111'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 8, 0),
#   'is_committed': True},
#  {'id': UUID('13f97e1c-8252-41f6-bdfb-2e7f728f66c5'),
#   'patient_id': UUID('e63f4fe4-0564-420f-ac10-cd646f1c7e3d'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 8, 30),
#   'is_committed': True},
#  {'id': UUID('97c20d2a-9913-4a95-909f-d3ee4307c8f2'),
#   'patient_id': UUID('9f71ba9f-0e58-4742-bdf4-bbfc80a96bd6'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 9, 0),
#   'is_committed': False},
#  {'id': UUID('bdcd363e-383f-44d0-ac4e-eb1475db66ef'),
#   'patient_id': UUID('df8a7b1b-93fb-4009-9ae2-8f02ee55c859'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 9, 30),
#   'is_committed': True},
#  {'id': UUID('c4818737-1eb0-4f82-9c57-9b7205acca81'),
#   'patient_id': UUID('5d65d234-bf11-4138-a073-c56b6bcd25be'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 10, 0),
#   'is_committed': True},
#  {'id': UUID('3b9782a0-8975-49ba-90d8-db2ec802db19'),
#   'patient_id': UUID('055791da-c920-4162-bd0c-851fd9062c41'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 10, 30),
#   'is_committed': True},
#  {'id': UUID('6b6c6d1e-6ceb-4f34-bafb-3c0957e41e78'),
#   'patient_id': UUID('b9ab7624-02ea-4b99-9e4e-fffba7a3094d'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 11, 0),
#   'is_committed': True},
#  {'id': UUID('13941de6-837c-43f9-b18a-c8c3e3a9ef49'),
#   'patient_id': UUID('72148619-7327-4fab-b208-23d29b512fc5'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 11, 30),
#   'is_committed': True},
#  {'id': UUID('4fc1c376-7bdf-4ab5-bb3d-55e18a0bc1e5'),
#   'patient_id': UUID('ad1d9e09-b0a7-45d8-ac21-a269e8bbe98b'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 12, 0),
#   'is_committed': True},
#  {'id': UUID('94e48e67-9cbe-4185-8231-e3e1d11d49fd'),
#   'patient_id': UUID('153bddd5-af20-41f5-831a-59776aefbb93'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 12, 30),
#   'is_committed': False},
#  {'id': UUID('b5c8ac93-872a-4b73-b259-9dd76bb70a4c'),
#   'patient_id': UUID('18a4cd10-126d-482f-bbde-46510b8b2f2e'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 13, 0),
#   'is_committed': True},
#  {'id': UUID('fb9d6f11-4f41-4d79-81f0-697943d3ccc2'),
#   'patient_id': UUID('a9febddf-6492-460d-a457-aa02ac792c4b'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 13, 30),
#   'is_committed': True},
#  {'id': UUID('452c0d56-6289-446a-9c6d-864446cd09b4'),
#   'patient_id': UUID('7d5c9aff-2bb2-4492-80f7-ed5347d6c159'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 14, 0),
#   'is_committed': True},
#  {'id': UUID('67c423cf-e99f-4d65-b6e7-a2f21e2b9258'),
#   'patient_id': UUID('4a82cdbe-c83c-4903-8188-19dc2f6891ae'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 14, 30),
#   'is_committed': False},
#  {'id': UUID('d9879725-3177-4905-8a75-c4b8634598e3'),
#   'patient_id': UUID('e30fdd5d-67a6-4711-96cf-e9ff86de301e'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 15, 0),
#   'is_committed': True},
#  {'id': UUID('06adac15-7732-4493-bfd1-457272e8ac56'),
#   'patient_id': UUID('8652e15e-2cc7-4425-bec1-038985bf55b6'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 15, 30),
#   'is_committed': True},
#  {'id': UUID('4a826490-d49e-465c-b255-ba9f3fe4b4dc'),
#   'patient_id': UUID('2269b208-7ef2-4ecd-afc0-2b2fa34d1669'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 16, 0),
#   'is_committed': True},
#  {'id': UUID('97eebfeb-f84d-4ca3-a411-d09ff22d756c'),
#   'patient_id': UUID('bf49d7fe-df93-41dc-b33b-fcef4f37f5dc'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 16, 30),
#   'is_committed': False},
#  {'id': UUID('3f7bb807-d3e1-41db-8df2-e85dec6abd90'),
#   'patient_id': UUID('87f013ce-de35-4c94-bd2a-0ce8ad58ecf9'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 17, 0),
#   'is_committed': True},
#  {'id': UUID('c7f45749-4d2b-453d-8049-9ae62eec4616'),
#   'patient_id': UUID('cda5e46b-03d8-4661-9e5c-26c09635dda7'),
#   'doctor_id': UUID('deb58b14-cfd4-4d2a-a299-064dae7dd414'),
#   'appointment_datetime': datetime.datetime(2015, 3, 12, 17, 30),
#   'is_committed': True},
#  {'id': UUID('08703277-ba09-4796-b28e-961f6df7f604'),
#   'patient_id': UUID('5c31d1e1-d31f-4e1d-9767-56f558764291'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 8, 0),
#   'is_committed': True},
#  {'id': UUID('0bee7a11-0e61-4d6e-8ed2-efc89c8a6592'),
#   'patient_id': UUID('bf8e82c5-048e-4541-9a08-d2560f4a06f6'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 8, 30),
#   'is_committed': True},
#  {'id': UUID('9b72a0f5-5708-422a-b95e-a8f74f0947d9'),
#   'patient_id': UUID('872bea21-28e9-472e-b31c-9509edcc6f40'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 9, 0),
#   'is_committed': True},
#  {'id': UUID('dd6715a9-df79-401a-8c3d-c80e622150d9'),
#   'patient_id': UUID('8652e15e-2cc7-4425-bec1-038985bf55b6'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 9, 30),
#   'is_committed': True},
#  {'id': UUID('aba424b6-a7b9-4612-900b-aef08460b8da'),
#   'patient_id': UUID('fcd923bf-0d34-44c9-8203-6243a651e67e'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 10, 0),
#   'is_committed': True},
#  {'id': UUID('6ba8ec4d-01a4-405b-84f2-8aa021f50456'),
#   'patient_id': UUID('9c8a0c81-0673-4304-a947-0d6c4926a3de'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 10, 30),
#   'is_committed': False},
#  {'id': UUID('4c16aa80-8252-4da8-9744-abb5e16a85c3'),
#   'patient_id': UUID('1fa797ba-f440-40ab-b058-0e9c8b7d634e'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 11, 0),
#   'is_committed': True},
#  {'id': UUID('47128e05-ef9a-4617-9de9-580f6b4e1a0f'),
#   'patient_id': UUID('4c153d93-e10b-4d43-8efd-451969e0794b'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 11, 30),
#   'is_committed': False},
#  {'id': UUID('646e66ed-cebb-4298-bb36-2cb54aded894'),
#   'patient_id': UUID('ac4f088d-6791-4ca3-a566-d2a32b50da23'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 12, 0),
#   'is_committed': True},
#  {'id': UUID('b92747e4-d044-439e-8a37-81b0b73ed1af'),
#   'patient_id': UUID('c946fb66-7973-458b-9bbb-fecdc1ce224a'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 12, 30),
#   'is_committed': True},
#  {'id': UUID('f56bff47-374f-4abf-89b9-3149041603cb'),
#   'patient_id': UUID('c516e778-bb54-4bf1-ba9b-23c47bc35845'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 13, 0),
#   'is_committed': True},
#  {'id': UUID('97313e11-7f93-463c-b620-3acaeb13ef9b'),
#   'patient_id': UUID('2c4c009d-ee63-47c2-bc8b-a184232f0939'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 13, 30),
#   'is_committed': False},
#  {'id': UUID('38a06e21-4597-4b4d-b1ee-c623e8b795fd'),
#   'patient_id': UUID('ed0d4af4-d8dc-4e2e-9706-78af2d21abc8'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 14, 0),
#   'is_committed': True},
#  {'id': UUID('dfad30fb-62bc-4681-b8e2-5b5622a5cd91'),
#   'patient_id': UUID('9212c040-5d41-4ba7-a9e2-e0edb637f5ba'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 14, 30),
#   'is_committed': True},
#  {'id': UUID('be846ae2-3143-4e56-abe1-91100f0015f1'),
#   'patient_id': UUID('7769f46f-f397-421f-ba54-41304846b6e9'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 15, 0),
#   'is_committed': True},
#  {'id': UUID('4726a1df-922b-4d99-9601-e15f56348c3f'),
#   'patient_id': UUID('2b427bc2-7a0b-46db-a753-b070409133e7'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 15, 30),
#   'is_committed': False},
#  {'id': UUID('adc39df2-b6f0-4e0d-a8ba-0b0544497332'),
#   'patient_id': UUID('b3c6e1fb-e9b8-48ea-8e3c-55bc28a5c4c5'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 16, 0),
#   'is_committed': True},
#  {'id': UUID('8415ad9f-4c3c-4620-98e3-5944babe5d1e'),
#   'patient_id': UUID('f84234fd-27c4-4519-965e-7117f20c73b5'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 16, 30),
#   'is_committed': True},
#  {'id': UUID('88038111-638e-4206-81cd-b0dcf9277d6b'),
#   'patient_id': UUID('1a728054-f282-48e9-9918-96073ffde3ed'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 17, 0),
#   'is_committed': True},
#  {'id': UUID('744a7322-c6a7-4444-8865-877c2851ca91'),
#   'patient_id': UUID('e67845fd-ddcc-4ef9-96b1-879d0c3768ac'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 17, 30),
#   'is_committed': True},
#  {'id': UUID('589c247b-e362-42eb-9940-04d23b259274'),
#   'patient_id': UUID('2cd38217-a936-4687-88b5-b1ba7cfad444'),
#   'doctor_id': UUID('1c0cc72c-e3b6-484f-a932-c65de5468cee'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 18, 0),
#   'is_committed': True},
#  {'id': UUID('eb5116d0-bd8a-410e-b0d0-b7e1ef65c2b4'),
#   'patient_id': UUID('e2a157ce-2aff-46bc-b72c-fdf3ded48a2b'),
#   'doctor_id': UUID('a8b7ea59-e00e-47b5-a44e-91be7c2bc4f2'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 8, 0),
#   'is_committed': True},
#  {'id': UUID('2226ef7f-48fe-4743-8788-7b66ca8a9765'),
#   'patient_id': UUID('f61245ae-3aed-42da-8bd2-4981a3da62d3'),
#   'doctor_id': UUID('a8b7ea59-e00e-47b5-a44e-91be7c2bc4f2'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 8, 30),
#   'is_committed': True},
#  {'id': UUID('74a0e4b9-051c-41e6-a2c9-b545b3b3cc38'),
#   'patient_id': UUID('c099a2b8-23fa-49ce-bb39-97a78585bf69'),
#   'doctor_id': UUID('a8b7ea59-e00e-47b5-a44e-91be7c2bc4f2'),
#   'appointment_datetime': datetime.datetime(2015, 3, 13, 9, 0),
#   'is_committed': True},
#  ...]

# %% [markdown]
# Вставка в БД

# %%
conn = psycopg2.connect(
    dbname="test",
    user="postgres",
    password="1234",
    host="localhost",
    port="5432"
)
psycopg2.extras.register_uuid(conn)
# Out:
# <psycopg2._psycopg.type 'UUID' at 0x000001D00A8564D0>

# %%
cur = conn.cursor()
def insert_all(table_name, rows):
    values = ", ".join(["%s"] * len(rows[0].values()))
    template = f'insert into {table_name} ({", ".join(rows[0].keys())}) values ({values})'
    for row in rows:
        cur.execute(template, tuple(row.values()))

# %%
insert_all('clinic.drugs', drugs)
insert_all('clinic.patients', patients)
insert_all('clinic.patients_personalities', patients_personalities)
insert_all('clinic.patients_consumption', patients_consumption)
insert_all('clinic.doctors', doctors)
insert_all('clinic.patients_doctors_appointments', patients_doctors_appointments)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 insert_all('clinic.drugs', drugs)
#       2 insert_all('clinic.patients', patients)
#       3 insert_all('clinic.patients_personalities', patients_personalities)
#
# Cell In[18], line 6, in insert_all(table_name, rows)
#       4 template = f'insert into {table_name} ({", ".join(rows[0].keys())}) values ({values})'
#       5 for row in rows:
# ----> 6     cur.execute(template, tuple(row.values()))
#
# UniqueViolation: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "drugs_name_key"
# DETAIL:  Ключ "(name)=(Alcohol)" уже существует.

# %%
cur.close()
